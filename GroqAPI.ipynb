# %%
# !pip install -q groq
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.7/143.7 kB 5.4 MB/s eta 0:00:00

# %%
from groq import Groq
GROQ_API_KEY = "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"
client = Groq(api_key=GROQ_API_KEY)
response = client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[
        {
            "role": "user",
            "content": "Explain HITL in LangGraph in simple terms."
        }
    ]
)
print(response.choices[0].message.content)
# Out:
# HITL stands for Human-in-the-Loop. In the context of LangGraph, it refers to a process where human evaluators or annotators are involved in the development and improvement of the language model.
#
# Think of it like this: LangGraph is a smart AI model that can understand and generate human-like language. But, to make it even smarter and more accurate, human evaluators review and provide feedback on its responses. This feedback loop helps the model learn from its mistakes and improve over time.
#
# Here's a simple breakdown of the HITL process in LangGraph:
#
# 1. **Model generates response**: LangGraph generates a response to a given prompt or question.
# 2. **Human evaluation**: A human evaluator reviews the response to check its accuracy, relevance, and coherence.
# 3. **Feedback provided**: The human evaluator provides feedback on the response, highlighting what's correct, what's incorrect, and what needs improvement.
# 4. **Model learns and improves**: The feedback is used to update and fine-tune the LangGraph model, helping it to learn from its mistakes and generate better responses in the future.
#
# By involving humans in the loop, HITL helps to ensure that LangGraph provides high-quality and accurate responses, which is essential for applications like customer support, language translation, and more.

# %%
# !pip install -u langchain
