# %%
# !pip langchain langchain-community
# Out:
# ERROR: unknown command "langchain"

# %%
from langchain_core.prompts import ChatPromptTemplate

user_input=input('Enter your question')
# Out:
# Enter your question what is the capital of India

# %%
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder

prompt=ChatPromptTemplate.from_messages(
    [('system','Your are a dr dont answer anything apart from this domain'),
     MessagesPlaceholder(variable_name="chat_history"),
     ('human','{input}')]
)

# %%
# !pip install langchain langchain-groq langchain-community
from langchain_groq import ChatGroq
from langchain_groq import ChatGroq
from langchain_classic.chains import ConversationChain
# Out:
# Requirement already satisfied: langchain in /usr/local/lib/python3.12/dist-packages (1.3.13)
# Collecting langchain-groq
#   Downloading langchain_groq-1.1.3-py3-none-any.whl.metadata (2.9 kB)
# Collecting langchain-community
#   Downloading langchain_community-0.4.2-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.9 in /usr/local/lib/python3.12/dist-packages (from langchain) (1.4.9)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.5 in /usr/local/lib/python3.12/dist-packages (from langchain) (1.2.9)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain) (2.13.4)
# Collecting groq<1.0.0,>=0.30.0 (from langchain-groq)
#   Downloading groq-0.37.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (3.14.1)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community)
#   Downloading httpx_sse-0.4.3-py3-none-any.whl.metadata (9.7 kB)
# Collecting langchain-classic<2.0.0,>=1.0.7 (from langchain-community)
#   Downloading langchain_classic-1.0.8-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (0.10.2)
# Requirement already satisfied: numpy>=1.26.2 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (2.0.2)
# Collecting pydantic-settings<3.0.0,>=2.10.1 (from langchain-community)
#   Downloading pydantic_settings-2.15.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (6.0.3)
# Collecting requests<3.0.0,>=2.32.5 (from langchain-community)
#   Downloading requests-2.34.2-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (2.0.51)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (9.1.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.5.2)
# Requirement already satisfied: typing_extensions>=4.4 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (4.16.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.24.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (4.14.2)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (0.28.1)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (1.3.1)
# Collecting langchain-text-splitters<2.0.0,>=1.1.2 (from langchain-classic<2.0.0,>=1.0.7->langchain-community)
#   Downloading langchain_text_splitters-1.1.2-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (0.0.18)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (26.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (0.17.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.3.0,>=1.2.5->langchain) (4.1.1)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.3.0,>=1.2.5->langchain) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.3.0,>=1.2.5->langchain) (0.4.2)
# Requirement already satisfied: xxhash>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.3.0,>=1.2.5->langchain) (3.8.1)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: websockets>=15.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (15.0.1)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.5.0)
# Requirement already satisfied: certifi>=2023.5.7 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2026.6.17)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-community) (3.5.3)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.9->langchain) (3.1.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.5->langchain) (1.12.2)
# Downloading langchain_groq-1.1.3-py3-none-any.whl (20 kB)
# Downloading langchain_community-0.4.2-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 57.7 MB/s eta 0:00:00
# Downloading groq-0.37.1-py3-none-any.whl (137 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 11.9 MB/s eta 0:00:00
# Downloading httpx_sse-0.4.3-py3-none-any.whl (9.0 kB)
# Downloading langchain_classic-1.0.8-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 53.9 MB/s eta 0:00:00
# Downloading pydantic_settings-2.15.0-py3-none-any.whl (69 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.4/69.4 kB 5.9 MB/s eta 0:00:00
# Downloading requests-2.34.2-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 5.8 MB/s eta 0:00:00
# Downloading langchain_text_splitters-1.1.2-py3-none-any.whl (35 kB)
# Installing collected packages: requests, httpx-sse, pydantic-settings, groq, langchain-text-splitters, langchain-groq, langchain-classic, langchain-community
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.34.2 which is incompatible.
# Successfully installed groq-0.37.1 httpx-sse-0.4.3 langchain-classic-1.0.8 langchain-community-0.4.2 langchain-groq-1.1.3 langchain-text-splitters-1.1.2 pydantic-settings-2.15.0 requests-2.34.2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1062/317585878.py in <cell line: 0>()
#       2 from langchain_groq import ChatGroq
#       3 from langchain_groq import ChatGroq
# ----> 4 from langchain_classic.chains import ConversationChain
#
# /usr/lib/python3.12/importlib/_bootstrap.py in _handle_fromlist(module, fromlist, import_, recursive)
#
# /usr/local/lib/python3.12/dist-packages/langchain_classic/chains/__init__.py in __getattr__(name)
#      91
#      92 def __getattr__(name: str) -> Any:
# ---> 93     return importer(name)
#      94
#      95
#
# /usr/local/lib/python3.12/dist-packages/langchain_classic/_api/module_import.py in import_by_name(name)
#      71
#      72             try:
# ---> 73                 module = importlib.import_module(new_module)
#      74             except ModuleNotFoundError as e:
#      75                 if new_module.startswith("langchain_community"):
#
# /usr/lib/python3.12/importlib/__init__.py in import_module(name, package)
#      88                 break
#      89             level += 1
# ---> 90     return _bootstrap._gcd_import(name[level:], package, level)
#      91
#      92
#
# /usr/local/lib/python3.12/dist-packages/langchain_classic/chains/conversation/base.py in <module>
#       7
#       8 from langchain_classic.base_memory import BaseMemory
# ----> 9 from langchain_classic.chains.conversation.prompt import PROMPT
#      10 from langchain_classic.chains.llm import LLMChain
#      11 from langchain_classic.memory.buffer import ConversationBufferMemory
#
# /usr/local/lib/python3.12/dist-packages/langchain_classic/chains/conversation/prompt.py in <module>
#       1 from langchain_core.prompts.prompt import PromptTemplate
#       2
# ----> 3 from langchain_classic.memory.prompt import (
#       4     ENTITY_EXTRACTION_PROMPT,
#       5     ENTITY_MEMORY_CONVERSATION_TEMPLATE,
#
# /usr/local/lib/python3.12/dist-packages/langchain_classic/memory/__init__.py in <module>
#      23 from langchain_classic.memory.token_buffer import ConversationTokenBufferMemory
#      24 from langchain_classic.memory.vectorstore import VectorStoreRetrieverMemory
# ---> 25 from langchain_classic.memory.vectorstore_token_buffer_memory import (
#      26     ConversationVectorStoreTokenBufferMemory,  # avoid circular import
#      27 )
#
# /usr/local/lib/python3.12/dist-packages/langchain_classic/memory/vectorstore_token_buffer_memory.py in <module>
#      21 )
#      22 from langchain_classic.memory.chat_memory import BaseChatMemory
# ---> 23 from langchain_classic.text_splitter import RecursiveCharacterTextSplitter
#      24
#      25 DEFAULT_HISTORY_TEMPLATE = """
#
# /usr/local/lib/python3.12/dist-packages/langchain_classic/text_splitter.py in <module>
#       1 """Kept for backwards compatibility."""
#       2
# ----> 3 from langchain_text_splitters import (
#       4     Language,
#       5     RecursiveCharacterTextSplitter,
#
# /usr/local/lib/python3.12/dist-packages/langchain_text_splitters/__init__.py in <module>
#      18     RecursiveCharacterTextSplitter,
#      19 )
# ---> 20 from langchain_text_splitters.html import (
#      21     ElementType,
#      22     HTMLHeaderTextSplitter,
#
# /usr/local/lib/python3.12/dist-packages/langchain_text_splitters/html.py in <module>
#      28
#      29 try:
# ---> 30     import nltk
#      31
#      32     _HAS_NLTK = True
#
# /usr/local/lib/python3.12/dist-packages/nltk/__init__.py in <module>
#     151 from nltk.tag import *
#     152 from nltk.tokenize import *
# --> 153 from nltk.translate import *
#     154 from nltk.tree import *
#     155 from nltk.sem import *
#
# /usr/local/lib/python3.12/dist-packages/nltk/translate/__init__.py in <module>
#      22 from nltk.translate.bleu_score import sentence_bleu as bleu
#      23 from nltk.translate.ribes_score import sentence_ribes as ribes
# ---> 24 from nltk.translate.meteor_score import meteor_score as meteor
#      25 from nltk.translate.metrics import alignment_error_rate
#      26 from nltk.translate.stack_decoder import StackDecoder
#
# /usr/local/lib/python3.12/dist-packages/nltk/translate/meteor_score.py in <module>
#      11 from typing import Callable, Iterable, List, Tuple
#      12
# ---> 13 from nltk.corpus import WordNetCorpusReader, wordnet
#      14 from nltk.stem.api import StemmerI
#      15 from nltk.stem.porter import PorterStemmer
#
# /usr/local/lib/python3.12/dist-packages/nltk/corpus/__init__.py in <module>
#      62 import re
#      63
# ---> 64 from nltk.corpus.reader import *
#      65 from nltk.corpus.util import LazyCorpusLoader
#      66 from nltk.tokenize import RegexpTokenizer
#
# /usr/local/lib/python3.12/dist-packages/nltk/corpus/reader/__init__.py in <module>
#      55 """
#      56
# ---> 57 from nltk.corpus.reader.plaintext import *
#      58 from nltk.corpus.reader.util import *
#      59 from nltk.corpus.reader.api import *
#
# /usr/local/lib/python3.12/dist-packages/nltk/corpus/reader/plaintext.py in <module>
#      13
#      14 import nltk.data
# ---> 15 from nltk.corpus.reader.api import *
#      16 from nltk.corpus.reader.util import *
#      17 from nltk.tokenize import *
#
# /usr/local/lib/python3.12/dist-packages/nltk/corpus/reader/api.py in <module>
#      16 from itertools import chain
#      17
# ---> 18 from nltk.corpus.reader.util import *
#      19 from nltk.data import FileSystemPathPointer, PathPointer, ZipFilePathPointer
#      20
#
# /usr/lib/python3.12/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /usr/lib/python3.12/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /usr/lib/python3.12/importlib/_bootstrap.py in _load_unlocked(spec)
#
# /usr/lib/python3.12/importlib/_bootstrap_external.py in exec_module(self, module)
#
# /usr/lib/python3.12/importlib/_bootstrap_external.py in get_code(self, fullname)
#
# /usr/lib/python3.12/importlib/_bootstrap_external.py in get_data(self, path)
#
# KeyboardInterrupt:
