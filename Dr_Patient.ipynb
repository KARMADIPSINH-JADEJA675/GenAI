# %%
# !pip install datasets transformers accelerate tokenizers

# %%
from transformers import GPT2Tokenizer, GPT2LMHeadModel,DataCollatorForLanguageModeling,Trainer,TrainingArguments

from datasets import load_dataset

# %% [markdown]
# It seems the file `dr_patient.txt` was not found, causing a `FileNotFoundError`. Please make sure you have uploaded the file to your Colab environment. You can upload the file by clicking on the folder icon on the left sidebar, then clicking the 'Upload' button and selecting your `dr_patient.txt` file. Once uploaded, the file should be accessible at `/content/dr_patient.txt`.

# %%
dataset=load_dataset("text",data_files="/content/dr_patient.txt")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1961/1052704536.py in <cell line: 0>()
# ----> 1 dataset=load_dataset("text",data_files="/content/dr_patient.txt")
#
# /usr/local/lib/python3.12/dist-packages/datasets/load.py in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, **config_kwargs)
#    1390
#    1391     # Create a dataset builder
# -> 1392     builder_instance = load_dataset_builder(
#    1393         path=path,
#    1394         name=name,
#
# /usr/local/lib/python3.12/dist-packages/datasets/load.py in load_dataset_builder(path, name, data_dir, data_files, cache_dir, features, download_config, download_mode, revision, token, storage_options, **config_kwargs)
# ...

# %%
print('Files in /content directory:')
# !ls -F /content
# Out:
# Files in /content directory:
# sample_data/

# %%
dataset
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1961/48412968.py in <cell line: 0>()
# ----> 1 dataset
#
# NameError: name 'dataset' is not defined
